# %%
import pandas as pd
import numpy as np
import time

# %%
import requests
import json
from bs4 import BeautifulSoup as bs

# %%
from fake_useragent import UserAgent
ua = UserAgent()

# %%
def get_rest(category0, page, amount, ls_len) :
    url = "https://www.yelp.com/search?find_desc={0}&find_loc=San%20Francisco%2C%20CA&attrs=RestaurantsDelivery&start={1}".format(category0, page*amount)
    ua = UserAgent()
    headers = {
    'User-Agent': ua.random,
}
    res = requests.get(url = url, headers=headers)
    soup = bs(res.text, 'html.parser')
    
    names = soup.select('div.lemon--div__09f24__1mboc.leftRailSearchResultsContainer__09f24__3vlwA.border-color--default__09f24__R1nRO > div:nth-of-type(2) > ul > li > div > div > div > div.lemon--div__09f24__1mboc.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div:nth-of-type(1) > div > div.lemon--div__09f24__1mboc.mainAttributes__09f24__26-vh.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div > div:nth-of-type(1) > div > div > h4 > span > a')[2:-1]
    names = [name.text for name in names]
    
    rates = []
    for ls in range(5,ls_len):
        try :
            rate = soup.select('div.lemon--div__09f24__1mboc.leftRailSearchResultsContainer__09f24__3vlwA.border-color--default__09f24__R1nRO > div:nth-of-type(2) > ul > li:nth-of-type({}) > div > div > div > div.lemon--div__09f24__1mboc.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div:nth-of-type(1) > div > div.lemon--div__09f24__1mboc.mainAttributes__09f24__26-vh.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div > div:nth-of-type(2) > div > div > div.lemon--div__09f24__1mboc.attribute__09f24__3znwq.display--inline-block__09f24__FsgS4.margin-r1__09f24__BCulR.border-color--default__09f24__R1nRO > span > div'.format(ls))[0]
            time.sleep(1)
            rate = float(rate.get("aria-label").split(" ")[0])
            rates.append(rate)
        except :            
            rates.append("NA")
            
    time.sleep(3)        
    
    counts = []
    for ls in range(5,ls_len):
        try:
            p = soup.select('div.lemon--div__09f24__1mboc.leftRailSearchResultsContainer__09f24__3vlwA.border-color--default__09f24__R1nRO > div:nth-of-type(2) > ul > li:nth-of-type({}) > div > div > div > div.lemon--div__09f24__1mboc.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div:nth-of-type(1) > div > div.lemon--div__09f24__1mboc.mainAttributes__09f24__26-vh.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div > div:nth-of-type(2) > div > div > div:nth-of-type(2) > span'.format(ls))[0]
            counts.append(int(p.text))
        except:
            counts.append("NA")
            
    prices = []
    for ls in range(5,ls_len):
        try:
            k = soup.select('div.lemon--div__09f24__1mboc.leftRailSearchResultsContainer__09f24__3vlwA.border-color--default__09f24__R1nRO > div:nth-of-type(2) > ul > li:nth-of-type({}) > div > div > div > div.lemon--div__09f24__1mboc.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div:nth-of-type(1) > div > div.lemon--div__09f24__1mboc.mainAttributes__09f24__26-vh.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div > div:nth-of-type(3) > div > div > span:nth-of-type(1) > span'.format(ls))[0]
            time.sleep(1)
            price = k.text
            if price[-2:] != ', ':
                if price[0] == '$' :
                    prices.append(int(len(price)))
                else :
                    prices.append(0)
            else: 
                pirces.append(0)
        except:
            prices.append(0)

                
    time.sleep(3)

    cate1 = []
    cate2 = []
    cate3 = []
                                

    for ls in range(5,ls_len):
        try:
            categories = soup.select('div.lemon--div__09f24__1mboc.leftRailSearchResultsContainer__09f24__3vlwA.border-color--default__09f24__R1nRO > div:nth-of-type(2) > ul > li:nth-of-type({})  > div > div > div > div.lemon--div__09f24__1mboc.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div:nth-of-type(1) > div > div.lemon--div__09f24__1mboc.mainAttributes__09f24__26-vh.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div > div:nth-of-type(3) > div > div'.format(ls))[0]
            time.sleep(1)
            category = categories.text
            st = category.count("$")
            category = category[st:]
            d = category.split(", ")
            cate1.append(d[0])
            try : 
                cate2.append(d[1])
            except:
                cate2.append("NA") 
            try :
                cate3.append(d[2])
            except :
                cate3.append("NA")
        except:
            cate1.append("NA")
            cate2.append("NA")
            cate3.append("NA")

    urls = soup.select('div.lemon--div__09f24__1mboc.leftRailSearchResultsContainer__09f24__3vlwA.border-color--default__09f24__R1nRO > div:nth-of-type(2) > ul > li > div > div > div > div.lemon--div__09f24__1mboc.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div:nth-of-type(1) > div > div.lemon--div__09f24__1mboc.mainAttributes__09f24__26-vh.arrange-unit__09f24__1gZC1.arrange-unit-fill__09f24__O6JFU.border-color--default__09f24__R1nRO > div > div:nth-of-type(1) > div > div > h4 > span > a')[2:-1]
    urls = ["https://www.yelp.com" + url.get("href") for url in urls]
    
    print("crawling done")
    print("{0} {1} {2} {3} {4} {5} {6} {7}".format(len(names),len(urls),
                                                       len(rates),len(prices),
                                                       len(counts),len(cate1),
                                                        len(cate2),len(cate3)
                                                       ))
    print("names : ", names)
    print("urls : ", urls)
    print("rates : ", rates)
    print("prices : ", prices)
    print("counts : ", counts)
    print("cate1 : ", cate1)
    print("cate2 : ", cate2)
    print("cate3 : ", cate3)
    
    rest_df = pd.DataFrame({
        'name' : names,
        'url' : urls,
        'rate' : rates,
        'price' : prices,
        'count' : counts,
        'main_category' : category0,
        "category1" : cate1,
        "category2" : cate2,
        "category3" : cate3,
    })
    
    return rest_df

# %%
delivery_df = pd.DataFrame(columns = [ 'name', 'url', 'rate' ,'price','count','main_category',"category1","category2","category3"])

for i in range(0,8):
    temp_df = get_rest('delivery', i, 30, 35)
    delivery_df = pd.concat([delivery_df, temp_df], axis=0) 
    
delivery_df
# Out:
# crawling done
# 30 30 30 30 30 30 30 30
# names :  ['Gyu-Kaku Japanese BBQ', 'Dumpling Baby China Bistro', 'Chicken as Cluck', 'Keto Bake & Bowl', 'Kung Food', 'Grandma’s Kitchen', 'Beretta Pop Up', 'Mamahuhu', 'Chubby Noodle', 'Societea Teahouse & Eatery', 'Firepie', 'Thai Time Restaurant', 'The Italian Homemade Company', 'Chubby Noodle Chinese Take Out', 'Farmhouse Kitchen Thai Cuisine', 'House of Thai', 'HRD', 'Mr Dragon', 'Hoshinoya', 'YH-Beijing', 'Dumpling Time Thrive City', 'Catch Sushi Bento', 'Hummus Bodega', 'Za’atar', 'MaMa Ji’s', 'Krispy Krunchy Chicken', 'Cracked & Battered - Marina', 'Chang’s Kitchen', 'Terra Cotta Warrior', 'Auntie April’s Chicken-n-Waffles']
# ...

# %%
delivery_df.to_csv("delivery_df.csv")

# %%
reservation_df = pd.DataFrame(columns = [ 'name', 'url', 'rate' ,'price','count','main_category',"category1","category2","category3"])

for i in range(0,12):
    temp_df = get_res_rest('reservations', i, 20, 2, 22)
    reservation_df = pd.concat([reservation_df, temp_df], axis=0) 
    
reservation_df
# Out:
# crawling done
# 20 20 20 20 20 20 20 20
# names :  ['Beretta Pop Up', 'California Fish Market Restaurant', 'Osteria Bella', 'Alchemist Bar & Lounge', 'Il Casaro Pizzeria & Mozzarella Bar - North Beach Location', 'The Front Porch', 'Mission Rock Resort', 'CreoLa', 'Ozumo', 'Khamsa', 'Nara', 'Harborview Restaurant & Bar', 'Mona Lisa Restaurant', 'Spiazzo Ristorante', 'Noren Izakaya', 'Golden Crab House', 'Zero Zero', 'Troya', 'Vega', 'Sushi Hon']
# ...

# %%
reservation_df.to_csv("reservation_df.csv")

# %%
burger_df = pd.DataFrame(columns = [ 'name', 'url', 'rate' ,'price','count','main_category',"category1","category2","category3"])

for i in range(0,24):
    temp_df = get_rest('burgers', i, 10, 6, 16)
    burger_df = pd.concat([burger_df, temp_df], axis=0) 
    
burger_df
# Out:
# crawling done
# 10 10 10 10 10 10 10 10
# names :  ['Native Burger', 'Pearl’s Deluxe Burgers', 'Super Duper Burgers', 'Calibur', 'Uncle Boy’s', 'Roam Artisan Burgers', 'WesBurger ‘N’ More', 'Jenny’s Burgers', 'Belly', 'Hi-Way Burger & Fry']
# urls :  ['https://www.yelp.com/biz/native-burger-san-francisco?osq=burgers', 'https://www.yelp.com/biz/pearls-deluxe-burgers-san-francisco-3?osq=burgers', 'https://www.yelp.com/biz/super-duper-burgers-san-francisco-4?osq=burgers', 'https://www.yelp.com/biz/calibur-san-francisco?osq=burgers', 'https://www.yelp.com/biz/uncle-boys-san-francisco?osq=burgers', 'https://www.yelp.com/biz/roam-artisan-burgers-san-francisco-3?osq=burgers', 'https://www.yelp.com/biz/wesburger-n-more-san-francisco?osq=burgers', 'https://www.yelp.com/biz/jenny-s-burgers-san-francisco?osq=burgers', 'https://www.yelp.com/biz/belly-san-francisco?osq=burgers', 'https://www.yelp.com/biz/hi-way-burger-and-fry-san-francisco?osq=burgers']
# ...

# %%
burger_df.to_csv("burger_df.csv")

# %%
japanese_df = pd.DataFrame(columns = [ 'name', 'url', 'rate' ,'price','count','main_category',"category1","category2","category3"])

for i in range(0,24):
    temp_df = get_rest('japanese', i, 10, 6, 16)
    japanese_df = pd.concat([japanese_df, temp_df], axis=0) 
    print("==================== {}번쨰 페이지 완료 ====================".format(i))
    
japanese_df
# Out:
# crawling done
# 10 10 10 10 10 10 10 10
# names :  ['Gyu-Kaku Japanese BBQ', 'Kazoku Sushi', 'Nara Restaurant & Sake Bar', 'Akira Japanese Restaurant', 'Goemon Sushi', 'Ryoko’s', 'Marufuku Ramen SF', 'Hoshinoya', 'Koo', 'Volcano']
# urls :  ['https://www.yelp.com/biz/gyu-kaku-japanese-bbq-san-francisco-2?osq=japanese', 'https://www.yelp.com/biz/kazoku-sushi-san-francisco?osq=japanese', 'https://www.yelp.com/biz/nara-restaurant-and-sake-bar-san-francisco?osq=japanese', 'https://www.yelp.com/biz/akira-japanese-restaurant-san-francisco?osq=japanese', 'https://www.yelp.com/biz/goemon-sushi-san-francisco?osq=japanese', 'https://www.yelp.com/biz/ryokos-san-francisco?osq=japanese', 'https://www.yelp.com/biz/marufuku-ramen-sf-san-francisco?osq=japanese', 'https://www.yelp.com/biz/hoshinoya-san-francisco?osq=japanese', 'https://www.yelp.com/biz/koo-san-francisco?osq=japanese', 'https://www.yelp.com/biz/volcano-san-francisco?osq=japanese']
# ...

# %%
japanese_df.to_csv("japanese_df.csv")

# %%
chinese_df = pd.DataFrame(columns = [ 'name', 'url', 'rate' ,'price','count','main_category',"category1","category2","category3"])

for i in range(0,24):
    temp_df = get_rest('chinese', i, 10, 6, 16)
    chinese_df = pd.concat([chinese_df, temp_df], axis=0) 
    print("==================== {}번쨰 페이지 완료 ====================".format(i))
    
chinese_df
# Out:
# crawling done
# 10 10 10 10 10 10 10 10
# names :  ['San Tung', 'Dumpling Baby China Bistro', 'Kung Food', 'Hunan Home’s Restaurant', 'YH-Beijing', 'Mamahuhu', 'Dong Bei Mama', 'MaMa Ji’s', 'Heung Yuen Restaurant', 'Henry’s Hunan Restaurant']
# urls :  ['https://www.yelp.com/biz/san-tung-san-francisco-2?osq=chinese', 'https://www.yelp.com/biz/dumpling-baby-china-bistro-san-francisco-4?osq=chinese', 'https://www.yelp.com/biz/kung-food-san-francisco?osq=chinese', 'https://www.yelp.com/biz/hunan-homes-restaurant-san-francisco?osq=chinese', 'https://www.yelp.com/biz/yh-beijing-san-francisco-7?osq=chinese', 'https://www.yelp.com/biz/mamahuhu-san-francisco-2?osq=chinese', 'https://www.yelp.com/biz/dong-bei-mama-san-francisco?osq=chinese', 'https://www.yelp.com/biz/mama-jis-san-francisco-2?osq=chinese', 'https://www.yelp.com/biz/heung-yuen-restaurant-san-francisco?osq=chinese', 'https://www.yelp.com/biz/henrys-hunan-restaurant-san-francisco-9?osq=chinese']
# ...

# %%
chinese_df.to_csv("chinese_df.csv")

# %%
mexican_df = pd.DataFrame(columns = [ 'name', 'url', 'rate' ,'price','count','main_category',"category1","category2","category3"])

for i in range(0,24):
    temp_df = get_rest('mexican', i, 10, 6, 16)
    mexican_df = pd.concat([mexican_df, temp_df], axis=0) 
    
mexican_df
# Out:
# crawling done
# 10 10 10 10 10 10 10 10
# names :  ['Tacorgasmico', 'The Little Chihuahua', 'Don Pistos', 'Pancho Villa Taqueria', 'El Capitan Taqueria', 'Casa Barajas', 'Taqueria Los Mayas', 'La Corneta Taqueria', 'Bueno Mexicali Grill', 'Garaje']
# urls :  ['https://www.yelp.com/biz/tacorgasmico-san-francisco-2?osq=mexican', 'https://www.yelp.com/biz/the-little-chihuahua-san-francisco?osq=mexican', 'https://www.yelp.com/biz/don-pistos-san-francisco-2?osq=mexican', 'https://www.yelp.com/biz/pancho-villa-taqueria-san-francisco?osq=mexican', 'https://www.yelp.com/biz/el-capitan-taqueria-san-francisco-5?osq=mexican', 'https://www.yelp.com/biz/casa-barajas-san-francisco?osq=mexican', 'https://www.yelp.com/biz/taqueria-los-mayas-san-francisco?osq=mexican', 'https://www.yelp.com/biz/la-corneta-taqueria-san-francisco-2?osq=mexican', 'https://www.yelp.com/biz/bueno-mexicali-grill-san-francisco-2?osq=mexican', 'https://www.yelp.com/biz/garaje-san-francisco?osq=mexican']
# ...

# %%
mexican_df.to_csv("mexican_df.csv")

# %%
italian_df = pd.DataFrame(columns = [ 'name', 'url', 'rate' ,'price','count','main_category',"category1","category2","category3"])

for i in range(0,24):
    temp_df = get_rest('italian', i, 10, 6, 16)
    italian_df = pd.concat([italian_df, temp_df], axis=0)
    print("==================== {}번쨰 페이지 완료 ====================".format(i))
    
italian_df
# Out:
# crawling done
# 10 10 10 10 10 10 10 10
# names :  ['Bella Trattoria', 'Sotto Mare Oysteria & Seafood', 'The Italian Homemade Company', 'The Italian Homemade Company', 'Poesia', 'Trattoria da Vittorio - San Francisco', 'Barzotto', 'Roma Antica', 'La Traviata', 'Trattoria Contadina']
# ...

# %%
italian_df.to_csv("italian_df.csv")

# %%
thai_df = pd.DataFrame(columns = [ 'name', 'url', 'rate' ,'price','count','main_category',"category1","category2","category3"])

for i in range(0,24):
    temp_df = get_rest('thai', i, 10, 6, 16)
    thai_df = pd.concat([thai_df, temp_df], axis=0) 
    
thai_df
# Out:
# crawling done
# 10 10 10 10 10 10 10 10
# names :  ['Farmhouse Kitchen Thai Cuisine', 'Thai Time Restaurant', 'Thai House Express', 'Ploy II', 'Lers Ros', 'Regent Thai Restaurant', 'Rin’s Thai Restaurant', 'House of Thai', 'Amphawa', 'Marnee Thai']
# urls :  ['https://www.yelp.com/biz/farmhouse-kitchen-thai-cuisine-san-francisco?osq=thai', 'https://www.yelp.com/biz/thai-time-restaurant-san-francisco?osq=thai', 'https://www.yelp.com/biz/thai-house-express-san-francisco-2?osq=thai', 'https://www.yelp.com/biz/ploy-ii-san-francisco?osq=thai', 'https://www.yelp.com/biz/lers-ros-san-francisco-2?osq=thai', 'https://www.yelp.com/biz/regent-thai-restaurant-san-francisco-2?osq=thai', 'https://www.yelp.com/biz/rins-thai-restaurant-san-francisco?osq=thai', 'https://www.yelp.com/biz/house-of-thai-san-francisco-2?osq=thai', 'https://www.yelp.com/biz/amphawa-san-francisco-2?osq=thai', 'https://www.yelp.com/biz/marnee-thai-san-francisco?osq=thai']
# ...

# %%
thai_df.to_csv("thai_df.csv")

# %%
resturant_df = pd.concat([delivery_df, reservation_df, thai_df, italian_df, mexican_df, chinese_df, burger_df, japanese_df], axis=0)
resturant_df.reset_index(drop=True, inplace=True)

# %%
resturant_df.to_csv("resturant_df.csv")

# %%
resturant_df
# Out:
#                              name  \
# 0           Gyu-Kaku Japanese BBQ
# 1      Dumpling Baby China Bistro
# 2                Chicken as Cluck
# 3                Keto Bake & Bowl
# 4                       Kung Food
# ...                           ...
# 1915  Toppu Ramen & Dim Sum House
# 1916                 Mikado Sushi
# 1917        Rock Japanese Cuisine
# 1918                      Riceful
# 1919                   Sushinista
#
#                                                     url rate price count  \
# 0     https://www.yelp.com/biz/gyu-kaku-japanese-bbq...   NA     0    NA
# 1     https://www.yelp.com/biz/dumpling-baby-china-b...  4.5     0     6
# 2     https://www.yelp.com/biz/chicken-as-cluck-san-...    5     0    44
# 3     https://www.yelp.com/biz/keto-bake-and-bowl-sa...    4     2   143
# 4     https://www.yelp.com/biz/kung-food-san-francis...    5     0     2
# ...                                                 ...  ...   ...   ...
# ...
